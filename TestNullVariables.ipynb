# %%
import pandas as pd

data = pd.read_csv("./Road_Accident_Data/Road-Accident.csv")
data.head()
# Out:
# /Users/rajatrasal/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   accident_index  vehicle_reference  vehicle_type  towing_and_articulation  \
# 0  201506E098757                  2             9                        0
# 1  201506E098766                  1             9                        0
# 2  201506E098766                  2             9                        0
# 3  201506E098777                  1            20                        0
# 4  201506E098780                  1             9                        0
#
#    vehicle_manoeuvre  vehicle_location-restricted_lane  junction_location  \
# 0                 18                                 0                  8
# 1                  9                                 0                  8
# ...

# %%
list(data.columns.values)[-14:]
# Out:
# ['casualty_reference',
#  'casualty_class',
#  'sex_of_casualty',
#  'age_of_casualty',
#  'age_band_of_casualty',
#  'casualty_severity',
#  'pedestrian_location',
#  'pedestrian_movement',
#  'car_passenger',
#  'bus_or_coach_passenger',
#  'pedestrian_road_maintenance_worker',
#  'casualty_type',
#  'casualty_home_area_type',
#  'casualty_imd_decile']

# %%
data.columns.values
# Out:
# array(['accident_index', 'vehicle_reference', 'vehicle_type',
#        'towing_and_articulation', 'vehicle_manoeuvre',
#        'vehicle_location-restricted_lane', 'junction_location',
#        'skidding_and_overturning', 'hit_object_in_carriageway',
#        'vehicle_leaving_carriageway', 'hit_object_off_carriageway',
#        '1st_point_of_impact', 'was_vehicle_left_hand_drive?',
#        'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver',
#        'age_band_of_driver', 'engine_capacity_(cc)', 'propulsion_code',
#        'age_of_vehicle', 'driver_imd_decile', 'driver_home_area_type',
#        'vehicle_imd_decile',
#        'NUmber_of_Casualities_unique_to_accident_index',
#        'No_of_Vehicles_involved_unique_to_accident_index',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'latitude', 'police_force', 'accident_severity',
#        'number_of_vehicles', 'number_of_casualties', 'date',
# ...

# %%
import numpy as np
# If unclean data is having predictions made on it, then this method will fail.

# find all cols with null values 
# look up their accident_index in the dataframe 
# then fill in the missing ones

# Going through every row and selecting it if there is a null element in it.
# Then we select acciddnrt indicies from these and select the unique ones/.
unique_accident_index = list(set(data[data.isnull().any(axis=1)]['accident_index']))

#for accident_index in unique_accident_index[0:5]:
    
def fill_null_indices(j):
    x = data.loc[data['accident_index'] == j]
    indices = x.index
    null_indices = x.index[x.isnull().any(axis=1)].tolist()
    not_null_index = 0
    for i in indices:
        if i not in null_indices:
            not_null_index = i
            break
    fill_data = data.iloc[not_null_index, -14:]
    for i in null_indices:
        data.iloc[i, -14:] = fill_data

#print(len(unique_accident_index))

for c, j in enumerate(unique_accident_index):
    fill_null_indices(j)
        
#data.loc[data['accident_index'] == unique_accident_index[j]]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-ea1e4cd34612> in <module>()
#      28
#      29 for c, j in enumerate(unique_accident_index):
# ---> 30     fill_null_indices(j)
#      31
#      32 #data.loc[data['accident_index'] == unique_accident_index[j]]
#
# <ipython-input-139-ea1e4cd34612> in fill_null_indices(j)
#      23     fill_data = data.iloc[not_null_index, -14:]
#      24     for i in null_indices:
# ---> 25         data.iloc[i, -14:] = fill_data
#      26
#      27 #print(len(unique_accident_index))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# ...
